# %%
import matplotlib as plot 
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(100, 4), columns='A B C D'.split())
print(df.head())
df.plot.hist()
# Out:
#           A         B         C         D
# 0 -0.121137  1.405797  1.131142  3.243081
# 1 -0.936534  1.534254  2.004937  1.900701
# 2  0.060530 -0.624250 -1.330692 -0.193085
# 3 -0.747243 -0.545575 -0.465516  0.994859
# 4  0.028047 -0.608156 -1.302870  1.185396
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.DataFrame(np.random.randn(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot()
print(df.head)
df.plot.hist()
plt.xlabel('x')
plt.ylabel('y')
# Out:
# <bound method NDFrame.head of           a         b         c         d
# 0  0.160557 -0.884851 -2.017488 -0.997988
# 1 -1.233700  0.794077  0.221289 -1.455129
# 2 -1.290261  1.460380 -0.424072  1.367921
# 3  1.409992 -0.025749 -1.613390  0.712454
# 4 -0.127173 -1.075687  0.304996 -1.109099
# 5 -1.012547  1.229608  0.561062 -0.361521
# 6  0.703936  1.057644  0.500647 -1.328280
# 7  1.306997  0.657192  0.268051  0.682508
# 8 -0.732871 -0.648898 -0.042791 -1.267770
# 9 -0.696261  0.736160 -0.001972 -1.586650>
# Text(0, 0.5, 'y')

# %%
 # Scatter chart using pairs of points
import matplotlib.pyplot as plt
from pylab import randn
 
x, y = randn(2, 100)
plt.scatter(x, y, color='red', marker='o')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter plot pythonspot.com')
plt.show()
