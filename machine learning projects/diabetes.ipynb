# %% [markdown]
# ## Scikit-learn Project using Diabetes data
# ### Gotten from scikit-learn cheatsheet from scikit-learn platform

# %% [markdown]
# ### 1. Loading the data

# %%
# Classification
from sklearn import datasets
X,y = datasets.load_wine(return_X_y=True)

# %%
# Regression
diabetes = datasets.load_diabetes()
X,y = diabetes.data, diabetes.target

# %% [markdown]
# ### 2. Training and testing data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### 3. Preprocessing the data

# %%
# Standardization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.fit_transform(X_test)

# %%
# Normalization
from sklearn.preprocessing import Normalizer

norm = Normalizer()
norm_X_train = norm.fit_transform(X_train)
norm_X_test = norm.transform(X_test)

# %%
# Binarization
from sklearn.preprocessing import Binarizer

binary = Binarizer(threshold=1.1)
binary_X = binary.fit_transform(X)

# %%
# Encoding categorical features

from sklearn.preprocessing import LabelEncoder

lab_enc = LabelEncoder()
y = lab_enc.fit_transform(y)

# %%
# Imputer
from sklearn.impute import SimpleImputer
import numpy as np

imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mean.fit_transform(X_train)
# Out:
# array([[ 0.01264814,  0.05068012,  0.00241654, ..., -0.03949338,
#          0.00370906,  0.07348023],
#        [-0.10722563, -0.04464164, -0.07734155, ..., -0.0763945 ,
#         -0.04257085, -0.0052198 ],
#        [ 0.02717829,  0.05068012, -0.03530688, ..., -0.00259226,
#         -0.01495969, -0.05078298],
#        ...,
#        [ 0.05987114, -0.04464164, -0.02129532, ...,  0.07120998,
#          0.07912244,  0.13561183],
#        [-0.07816532, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.01811369, -0.08391984],
#        [ 0.04170844,  0.05068012,  0.07139652, ...,  0.03430886,
#          0.07340696,  0.08590655]])

# %% [markdown]
# ### 3. Supervised Learning Model

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
# Support Vector Machines
from sklearn.svm import SVC
svm_svc = SVC(kernel='linear', C=1, random_state=42)

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB

gbn = GaussianNB()

# %% [markdown]
# ### 4. Unsupervised Learning Model

# %%
# Principal Component Analysis (PCA)
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
# K-Means Clustering
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, random_state=0)

# %% [markdown]
# ### 5. Model Fitting

# %%
# Supervised learning
lr.fit(X_train, y_train)
svm_svc.fit(X_train, y_train)
# Out:
# SVC(C=1, kernel='linear', random_state=42)

# %%
# Unsupervised learning
model = pca.fit_transform(X_train)
kmeans.fit(X_train)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %% [markdown]
# ### 6. Prediction

# %%
# Supervised learning
y_pred = lr.predict(X_test)
y_pred = svm_svc.predict(X_test)

# %%
# Unsupervised learning
y_pred = kmeans.predict(X_test)

# %% [markdown]
# ### 6. Evaluation

# %%
# Accuracy score
lr.score(X_test, y_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.0

# %%
# Classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00
#        200.0       0.00      0.00      0.00       1.0
#        214.0       0.00      0.00      0.00       1.0
#        215.0       0.00      0.00      0.00       1.0
#        217.0       0.00      0.00      0.00       1.0
#        219.0       0.00      0.00      0.00       1.0
#        230.0       0.00      0.00      0.00       1.0
#        232.0       0.00      0.00      0.00       1.0
#        235.0       0.00      0.00      0.00       1.0
#        244.0       0.00      0.00      0.00       1.0
#        252.0       0.00      0.00      0.00       1.0
#        257.0       0.00      0.00      0.00       1.0
#        264.0       0.00      0.00      0.00       1.0
#        270.0       0.00      0.00      0.00       1.0
#        275.0       0.00      0.00      0.00       1.0
#        276.0       0.00      0.00      0.00       1.0
#        281.0       0.00      0.00      0.00       1.0
#        283.0       0.00      0.00      0.00       1.0
#        297.0       0.00      0.00      0.00       1.0
#        302.0       0.00      0.00      0.00       1.0
#        317.0       0.00      0.00      0.00       1.0
#        321.0       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00      89.0
#    macro avg       0.00      0.00      0.00      89.0
# weighted avg       0.00      0.00      0.00      89.0
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 28309.696629213482

# %%
# R2 score 
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# -4.520690225664238

# %%
# Adjusted Rand Index 
from sklearn.metrics import adjusted_rand_score 
adjusted_rand_score(y_test, y_pred)
# Out:
# 0.0006963858447657236

# %% [markdown]
# ### 7. Cross-Validation

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(lr, X, y, cv=5, scoring='f1_macro')
# Out:
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:1011: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 137, in __call__
#     score = scorer._score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1271, in f1_score
#     return fbeta_score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1463, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1539, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:1011: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 137, in __call__
#     score = scorer._score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1271, in f1_score
#     return fbeta_score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1463, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1539, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:1011: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 137, in __call__
#     score = scorer._score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1271, in f1_score
#     return fbeta_score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1463, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1539, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:1011: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 137, in __call__
#     score = scorer._score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1271, in f1_score
#     return fbeta_score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1463, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1539, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:1011: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 137, in __call__
#     score = scorer._score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 350, in _score
#     return self._sign * self._score_func(y_true, y_pred, **scoring_kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 213, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1271, in f1_score
#     return fbeta_score(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1463, in fbeta_score
#     _, _, f, _ = precision_recall_fscore_support(
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 186, in wrapper
#     return func(*args, **kwargs)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1767, in precision_recall_fscore_support
#     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 1539, in _check_set_wise_labels
#     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#   File "/home/prigii/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py", line 94, in _check_targets
#     raise ValueError(
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
#
#   warnings.warn(
# array([nan, nan, nan, nan, nan])

# %% [markdown]
# ### 8. Model Tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10]}
model = GridSearchCV(SVC(), parameters)
model.fit(X_train, y_train)
print(model.best_score__)
print(model.best_estimator_)
# Out:
# /home/prigii/.local/lib/python3.10/site-packages/sklearn/model_selection/_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 6
#       4 model = GridSearchCV(SVC(), parameters)
#       5 model.fit(X_train, y_train)
# ----> 6 print(model.best_score__)
#       7 print(model.best_estimator_)
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_score__'
